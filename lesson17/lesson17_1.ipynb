# %% [markdown]
# https://www.perplexity.ai/search/541099c9-ea3f-4aaa-98b2-53af4156f3cc

# %% [markdown]
# 需要安裝jinja2套件

# %%
#Styler.format()
#Style.format_index()
#Style.relabel_index()

import pandas as pd
import numpy as np 

df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
type(df.style)

display(df)
s = df.style\
.format(precision=3, thousands=",", decimal='.')\
.format_index(str.upper,axis=1)\
.relabel_index(["列1","列2"])

s
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230
# <style type="text/css">
# </style>
# <table id="T_e84ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e84ee_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_e84ee_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_e84ee_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e84ee_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_e84ee_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_e84ee_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_e84ee_row0_col2" class="data row0 col2" >1.123</td>
#     </tr>
#     <tr>
#       <th id="T_e84ee_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_e84ee_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_e84ee_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_e84ee_row1_col2" class="data row1 col2" >1,000.230</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                         index=pd.date_range(start="2025-01-10", periods=10),
                         columns=["東京","台北"]
                         )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2025-01-10 to 2025-01-19
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   東京      10 non-null     float64
#  1   台北      10 non-null     float64
# dtypes: float64(2)
# memory usage: 240.0 bytes

# %%
weather_df = pd.DataFrame(np.random.rand(600,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=600),
                          columns=["東京","台北"]
                          )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 600 entries, 2024-01-01 to 2025-08-22
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   東京      600 non-null    float64
#  1   台北      600 non-null    float64
# dtypes: float64(2)
# memory usage: 14.1 KB

# %%
#因為索引是datetime的資料
weather_df.loc['2024-01-10':'2024-01-30']
weather_df.loc['2024-01']
weather_df.loc['2024']
# Out:
#                   東京        台北
# 2024-01-01  0.000300  2.922608
# 2024-01-02  0.822530  4.827855
# 2024-01-03  1.354977  1.865658
# 2024-01-04  3.515765  1.748432
# 2024-01-05  0.263995  1.729448
# ...              ...       ...
# 2024-12-27  3.052898  0.742635
# 2024-12-28  2.270423  1.876864
# 2024-12-29  4.595823  0.602177
# 2024-12-30  3.876371  2.380349
# 2024-12-31  0.897799  0.087592
#
# [366 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.plot(weather_df.index,weather_df['東京'],label='Tokyyo',linestyle='',marker='.')
plt.show()
plt.close()

# %%
weather_df.plot(linestyle='',marker='.')
# Out:
# <Axes: >
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 26481 (\N{CJK UNIFIED IDEOGRAPH-6771}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 20140 (\N{CJK UNIFIED IDEOGRAPH-4EAC}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 21488 (\N{CJK UNIFIED IDEOGRAPH-53F0}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 21271 (\N{CJK UNIFIED IDEOGRAPH-5317}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26481 (\N{CJK UNIFIED IDEOGRAPH-6771}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20140 (\N{CJK UNIFIED IDEOGRAPH-4EAC}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21488 (\N{CJK UNIFIED IDEOGRAPH-53F0}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21271 (\N{CJK UNIFIED IDEOGRAPH-5317}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
weather_df = pd.DataFrame(np.random.rand(50,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=50),
                          columns=["Tokyo","Taipei"]
                          )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2024-01-01 to 2024-02-19
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tokyo   50 non-null     float64
#  1   Taipei  50 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
#因為索引是datetime的資料
# weather_df.loc['2024-01-10':'2024-01-30']
# weather_df.loc['2024-01']
# weather_df.loc['2024']
# Out:
#                Tokyo    Taipei
# 2024-01-01  2.591735  2.256329
# 2024-01-02  1.294186  3.580988
# 2024-01-03  4.780128  1.131753
# 2024-01-04  3.411001  4.964229
# 2024-01-05  3.411523  3.492417
# 2024-01-06  4.865663  2.532093
# 2024-01-07  0.372777  1.668623
# 2024-01-08  2.406939  4.333916
# 2024-01-09  0.115253  2.069083
# 2024-01-10  0.489294  3.769412
# 2024-01-11  4.710182  3.645830
# 2024-01-12  2.412864  1.116467
# 2024-01-13  0.588989  3.267818
# 2024-01-14  0.273000  0.299563
# 2024-01-15  3.028343  1.743529
# 2024-01-16  0.831224  0.310707
# 2024-01-17  1.236726  0.625555
# 2024-01-18  1.963717  3.987732
# 2024-01-19  0.937735  1.217454
# 2024-01-20  4.968247  0.231422
# 2024-01-21  0.069414  1.963321
# 2024-01-22  1.299721  0.454001
# 2024-01-23  2.052332  0.898935
# 2024-01-24  1.135114  1.779104
# 2024-01-25  4.987261  4.753644
# 2024-01-26  1.840913  3.445940
# 2024-01-27  0.542353  0.693949
# 2024-01-28  2.519104  4.093433
# 2024-01-29  0.030674  4.944370
# 2024-01-30  3.089969  3.078564
# 2024-01-31  0.434505  2.228389
# 2024-02-01  1.173001  0.023538
# 2024-02-02  4.401357  2.868421
# 2024-02-03  0.640831  2.394397
# 2024-02-04  3.643974  2.304386
# 2024-02-05  4.603027  2.013848
# 2024-02-06  3.287257  2.094892
# 2024-02-07  1.466168  0.282679
# 2024-02-08  1.597091  3.620116
# 2024-02-09  3.070772  3.307142
# 2024-02-10  4.247962  4.154761
# 2024-02-11  0.329094  0.861201
# 2024-02-12  3.003390  3.769953
# 2024-02-13  3.111624  1.505011
# 2024-02-14  0.238398  2.970873
# 2024-02-15  4.829325  1.468038
# 2024-02-16  3.597359  4.068584
# 2024-02-17  4.666268  4.453537
# 2024-02-18  2.516556  0.932008
# 2024-02-19  2.132921  1.550376

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.plot(weather_df.index,weather_df['Tokyo'],label='Tokyyo',linestyle='',marker='.')
axes.plot(weather_df.index,weather_df['Taipei'],label='Taiepi',linestyle='',marker='.')
plt.show()
plt.close()

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
weather_df.plot(ax=axes,linestyle='',marker='.')
plt.show()
plt.close()

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )

weather_df.loc['2024-01-01':'2024-01-07'].style.pipe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       1 weather_df = pd.DataFrame(np.random.rand(10,2)*5,
#       2                           index=pd.date_range(start="2024-01-01", periods=10),
#       3                           columns=["Tokyo","Taipei"]
#       4                           )
# ----> 6 weather_df.loc['2024-01-01':'2024-01-07'].style.pipe()
#
# TypeError: Styler.pipe() missing 1 required positional argument: 'func'

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def rain_condition(v):
    if v < 1.75:
        return "乾燥"
    elif v < 2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_e290b">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e290b_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_e290b_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e290b_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_e290b_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_e290b_row0_col1" class="data row0 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_e290b_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_e290b_row1_col0" class="data row1 col0" >大雨</td>
#       <td id="T_e290b_row1_col1" class="data row1 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_e290b_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_e290b_row2_col0" class="data row2 col0" >小雨</td>
#       <td id="T_e290b_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_e290b_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_e290b_row3_col0" class="data row3 col0" >大雨</td>
#       <td id="T_e290b_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_e290b_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_e290b_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_e290b_row4_col1" class="data row4 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_e290b_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_e290b_row5_col0" class="data row5 col0" >乾燥</td>
#       <td id="T_e290b_row5_col1" class="data row5 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_e290b_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_e290b_row6_col0" class="data row6 col0" >小雨</td>
#       <td id="T_e290b_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(1234)
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
display(weather_df)
def rain_condition(v):
    if v < 1.75:
        return "乾燥"
    elif v < 2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
    styler.background_gradient(axis=None,vmin=1,vmax=5,cmap="PuBuGn")
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s.to_excel('weaer_condition.xlsx')
# Out:
#                Tokyo    Taipei
# 2024-01-01  0.957597  3.110544
# 2024-01-02  2.188639  3.926793
# 2024-01-03  3.899879  1.362963
# 2024-01-04  1.382321  4.009361
# 2024-01-05  4.790697  4.379663
# 2024-01-06  1.789086  2.504976
# 2024-01-07  3.417315  3.563510
# 2024-01-08  1.851254  2.805981
# 2024-01-09  2.515416  0.068842
# 2024-01-10  3.864133  4.413206
